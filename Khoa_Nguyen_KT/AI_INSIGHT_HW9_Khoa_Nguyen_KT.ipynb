# %% [markdown]
# Class: AI INSIGHT
#
# Name: Nguyen Tho Anh Khoa
#
# Facebook: Khoa Nguyen KT

# %% [markdown]
# # Multilayer Perceptron – Exercise 1

# %% [markdown]
# ##  1) Các bạn đọc hiểu các file code mẫu dùng MLP cho Fashion-MNIST và Cifar10
#
# ##  a. 1.MLP-Fashion-MNIST-KerasData-Sigmoid.ipynb
#
# ##  b. 2.MLP-Fashion-MNIST-KerasData-ReLU.ipynb
#
# ## c. 1.MLP-Cifar10-KerasData-Sigmoid.ipynb
#
# ## d. 2.MLP-Cifar10-KerasData-ReLU.ipynb

# %% [markdown]
# ### a. 1.MLP-Fashion-MNIST-KerasData-Sigmoid.ipynb

# %% [markdown]
# Đoạn code này sử dụng build-in dataset trong tensorflow, thay vì phải download và xử lý ảnh như homework trước.

# %%
import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images = test_images / 255.0

print(train_images.shape)
print(test_images.shape)
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28)
# (10000, 28, 28)

# %% [markdown]
# Đoạn code này:
# - Khởi tạo weight theo **Normal distribution**
# - Sử dụng **sigmoid** activation cho hidden layer
# - Optimizer là **sgd**

# %%
# RandomNormal, sigmoid and sgd

import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images  = test_images / 255.0

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='sigmoid', 
                       kernel_initializer=keras.initializers.RandomNormal(stddev=0.01),
                       bias_initializer=keras.initializers.Zeros()),
    keras.layers.Dense(10, activation='softmax', 
                       kernel_initializer=keras.initializers.RandomNormal(stddev=0.01),
                       bias_initializer=keras.initializers.Zeros())
])

model.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history_data = model.fit(train_images, train_labels,
                         validation_data=(test_images, test_labels), 
                         batch_size=1024, epochs=80, verbose=2)
# Out:
# Epoch 1/80
# 59/59 - 3s - loss: 2.3023 - accuracy: 0.1156 - val_loss: 2.3006 - val_accuracy: 0.1184
# Epoch 2/80
# 59/59 - 0s - loss: 2.2994 - accuracy: 0.1836 - val_loss: 2.2979 - val_accuracy: 0.1446
# Epoch 3/80
# 59/59 - 0s - loss: 2.2966 - accuracy: 0.2114 - val_loss: 2.2950 - val_accuracy: 0.2280
# Epoch 4/80
# 59/59 - 0s - loss: 2.2934 - accuracy: 0.2776 - val_loss: 2.2915 - val_accuracy: 0.3724
# Epoch 5/80
# 59/59 - 0s - loss: 2.2896 - accuracy: 0.3719 - val_loss: 2.2873 - val_accuracy: 0.3230
# Epoch 6/80
# 59/59 - 0s - loss: 2.2848 - accuracy: 0.3861 - val_loss: 2.2820 - val_accuracy: 0.3710
# Epoch 7/80
# 59/59 - 0s - loss: 2.2788 - accuracy: 0.4274 - val_loss: 2.2752 - val_accuracy: 0.3990
# Epoch 8/80
# 59/59 - 0s - loss: 2.2712 - accuracy: 0.4557 - val_loss: 2.2665 - val_accuracy: 0.4311
# Epoch 9/80
# 59/59 - 0s - loss: 2.2614 - accuracy: 0.4671 - val_loss: 2.2555 - val_accuracy: 0.4278
# Epoch 10/80
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['loss'], label = "train_loss")
plt.plot(history_data.history['val_loss'], label = "val_loss")
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['accuracy'], label = "train_accuracy")
plt.plot(history_data.history['val_accuracy'], label = "val_accuracy")
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# Đoạn code này:
# - Khởi tạo weight theo kỹ thuật **Xavier**
# - Sử dụng **sigmoid** activation cho hidden layer
# - Optimizer là **sgd**

# %%
# Xavier, sigmoid and sgd

import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images  = test_images / 255.0

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history_data = model.fit(train_images, train_labels,
                         validation_data=(test_images, test_labels), 
                         batch_size=1024, epochs=80, verbose=2)
# Out:
# Epoch 1/80
# 59/59 - 1s - loss: 2.2523 - accuracy: 0.2510 - val_loss: 2.1103 - val_accuracy: 0.3284
# Epoch 2/80
# 59/59 - 0s - loss: 2.0421 - accuracy: 0.4470 - val_loss: 1.9783 - val_accuracy: 0.5303
# Epoch 3/80
# 59/59 - 0s - loss: 1.9198 - accuracy: 0.5810 - val_loss: 1.8647 - val_accuracy: 0.6131
# Epoch 4/80
# 59/59 - 0s - loss: 1.8115 - accuracy: 0.6318 - val_loss: 1.7632 - val_accuracy: 0.6439
# Epoch 5/80
# 59/59 - 0s - loss: 1.7147 - accuracy: 0.6560 - val_loss: 1.6726 - val_accuracy: 0.6614
# Epoch 6/80
# 59/59 - 0s - loss: 1.6284 - accuracy: 0.6696 - val_loss: 1.5919 - val_accuracy: 0.6699
# Epoch 7/80
# 59/59 - 0s - loss: 1.5514 - accuracy: 0.6795 - val_loss: 1.5200 - val_accuracy: 0.6746
# Epoch 8/80
# 59/59 - 0s - loss: 1.4828 - accuracy: 0.6860 - val_loss: 1.4559 - val_accuracy: 0.6835
# Epoch 9/80
# 59/59 - 0s - loss: 1.4216 - accuracy: 0.6916 - val_loss: 1.3985 - val_accuracy: 0.6906
# Epoch 10/80
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['loss'], label = "train_loss")
plt.plot(history_data.history['val_loss'], label = "val_loss")
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['accuracy'], label = "train_accuracy")
plt.plot(history_data.history['val_accuracy'], label = "val_accuracy")
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# Đoạn code này:
# - Khởi tạo weight theo kỹ thuật **Xavier**
# - Sử dụng **sigmoid** activation cho hidden layer
# - Optimizer là **adam**

# %%
# sigmoid and adam

import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images  = test_images / 255.0

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_data = model.fit(train_images, train_labels, 
                    validation_data=(test_images, test_labels), 
                    batch_size=1024, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 59/59 - 1s - loss: 1.2616 - accuracy: 0.6295 - val_loss: 0.8323 - val_accuracy: 0.7450
# Epoch 2/50
# 59/59 - 0s - loss: 0.7135 - accuracy: 0.7797 - val_loss: 0.6526 - val_accuracy: 0.7869
# Epoch 3/50
# 59/59 - 0s - loss: 0.5902 - accuracy: 0.8100 - val_loss: 0.5740 - val_accuracy: 0.8070
# Epoch 4/50
# 59/59 - 0s - loss: 0.5276 - accuracy: 0.8246 - val_loss: 0.5302 - val_accuracy: 0.8184
# Epoch 5/50
# 59/59 - 0s - loss: 0.4897 - accuracy: 0.8334 - val_loss: 0.4999 - val_accuracy: 0.8277
# Epoch 6/50
# 59/59 - 0s - loss: 0.4641 - accuracy: 0.8406 - val_loss: 0.4806 - val_accuracy: 0.8294
# Epoch 7/50
# 59/59 - 0s - loss: 0.4451 - accuracy: 0.8459 - val_loss: 0.4679 - val_accuracy: 0.8350
# Epoch 8/50
# 59/59 - 0s - loss: 0.4299 - accuracy: 0.8503 - val_loss: 0.4572 - val_accuracy: 0.8364
# Epoch 9/50
# 59/59 - 0s - loss: 0.4181 - accuracy: 0.8541 - val_loss: 0.4457 - val_accuracy: 0.8403
# Epoch 10/50
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['loss'], label = "train_loss")
plt.plot(history_data.history['val_loss'], label = "val_loss")
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['accuracy'], label = "train_accuracy")
plt.plot(history_data.history['val_accuracy'], label = "val_accuracy")
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %%
# sigmoid and adam

import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images  = test_images / 255.0

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_data = model.fit(train_images, train_labels, 
                    validation_data=(test_images, test_labels), 
                    batch_size=1024, epochs=50, verbose=2)

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['loss'], label = "train_loss")
plt.plot(history_data.history['val_loss'], label = "val_loss")
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['accuracy'], label = "train_accuracy")
plt.plot(history_data.history['val_accuracy'], label = "val_accuracy")
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
#  1/ **Normal distribution**, **sigmoid**, **sgd**  -> train:70%, val:70%
#
#  2/ **Xavier**, **sigmoid**, **sgd**  -> train:77% val:76%
#
#  3/ **Xavier**, **sigmoid**, **adam**  -> train:90% val:88%
#
#  4/ **Xavier**, **sigmoid**, **adam**  -> train:92% val:87%
#
#  **=> Từ đây ta có thể thấy được:**
#
#  **- Dùng kỹ thuật khởi tạo xavier giúp tăng hội tụ nhanh hơn và độ chính xác tăng gần 6 ~ 7%. sau đó sử dụng adam optimizer giúp tăng thêm khoảng 12 ~ 13% acc. Tuy nhiên, cũng có 1 điều lưu ý là nếu như ta tăng thêm độ phức tạp của model (model sâu hơn, nhiều weight hơn thì có thể dẫn đến overfitting khi train tăng nhưng tập val lại giảm)**
#
# **- Ngoài ra quan sát hình vẽ acc và loss (cảu 1/ và 2/) cũng nhận thấy rằng khác epoch ban đầu học chưa ổn định nếu không dùng Xavier khởi tạo weight**
#
# **=> Việc khởi tạo weight bằng Xavier và dùng optimizer giúp cải thiện độ chính xác khá nhiều**

# %% [markdown]
# ### b. 2.MLP-Fashion-MNIST-KerasData-ReLU.ipynb

# %% [markdown]
# Đoạn code này:
# - Khởi tạo weight theo kỹ thuật **Xavier**
# - Sử dụng **relu** activation cho hidden layer
# - Optimizer là **adam**

# %%
# relu and adam

import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images  = test_images / 255.0

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_data = model.fit(train_images, train_labels, 
                    validation_data=(test_images, test_labels), 
                    batch_size=1024, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 59/59 - 1s - loss: 0.8711 - accuracy: 0.7134 - val_loss: 0.5935 - val_accuracy: 0.7987
# Epoch 2/50
# 59/59 - 0s - loss: 0.5163 - accuracy: 0.8257 - val_loss: 0.5182 - val_accuracy: 0.8221
# Epoch 3/50
# 59/59 - 0s - loss: 0.4603 - accuracy: 0.8431 - val_loss: 0.4719 - val_accuracy: 0.8376
# Epoch 4/50
# 59/59 - 0s - loss: 0.4258 - accuracy: 0.8543 - val_loss: 0.4500 - val_accuracy: 0.8440
# Epoch 5/50
# 59/59 - 0s - loss: 0.4040 - accuracy: 0.8603 - val_loss: 0.4306 - val_accuracy: 0.8526
# Epoch 6/50
# 59/59 - 0s - loss: 0.3862 - accuracy: 0.8672 - val_loss: 0.4184 - val_accuracy: 0.8565
# Epoch 7/50
# 59/59 - 0s - loss: 0.3739 - accuracy: 0.8703 - val_loss: 0.4195 - val_accuracy: 0.8516
# Epoch 8/50
# 59/59 - 0s - loss: 0.3596 - accuracy: 0.8757 - val_loss: 0.4007 - val_accuracy: 0.8586
# Epoch 9/50
# 59/59 - 0s - loss: 0.3467 - accuracy: 0.8797 - val_loss: 0.3926 - val_accuracy: 0.8623
# Epoch 10/50
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['loss'], label = "train_loss")
plt.plot(history_data.history['val_loss'], label = "val_loss")
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['accuracy'], label = "train_accuracy")
plt.plot(history_data.history['val_accuracy'], label = "val_accuracy")
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# **Có thể quan sát được khi thay hàm activation trong hidden layer thì sẽ giúp cho model nhanh hội tụ hơn trước 10 epoch data đã bị overfitting -> model học khá nhanh**

# %% [markdown]
# ### c. 1.MLP-Cifar10-KerasData-Sigmoid.ipynb

# %% [markdown]
# Đoạn code này thể hiện cách load built-in data (cifar10) trong tensorflow, tập train có 50000 ảnh và test có 10000 ảnh, là ảnh màu 3 channel RGB có kích thước là 32x32

# %%
import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.cifar10.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images = test_images / 255.0

print(train_images.shape)
print(test_images.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %% [markdown]
# Đoạn code thể hiện cách dùng matplotlib để show các ảnh trong data

# %%
import matplotlib.pyplot as plt 
import numpy as np 

fig =plt.figure(figsize=(12,12))

for i in range(10):
    X_train_i = train_images[train_labels[:,0]==i]    
    X_train_i = X_train_i[:10]
    
    for j in range(10):
        img = X_train_i[j].reshape(32,32,3)
        fig.add_subplot(10, 10, i*10 + j+1)
        plt.axis('off')
        plt.imshow(img, vmin=0, vmax=255)

# %%
# sigmoid and adam

import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.cifar10.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images  = test_images / 255.0

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(32,32,3)),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_data = model.fit(train_images, train_labels, 
                    validation_data=(test_images, test_labels), 
                    batch_size=1024, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 49/49 - 1s - loss: 2.3102 - accuracy: 0.1125 - val_loss: 2.2775 - val_accuracy: 0.1466
# Epoch 2/50
# 49/49 - 0s - loss: 2.1466 - accuracy: 0.1765 - val_loss: 2.0615 - val_accuracy: 0.1923
# Epoch 3/50
# 49/49 - 0s - loss: 2.0425 - accuracy: 0.2005 - val_loss: 2.0303 - val_accuracy: 0.2034
# Epoch 4/50
# 49/49 - 0s - loss: 2.0135 - accuracy: 0.2145 - val_loss: 1.9849 - val_accuracy: 0.2193
# Epoch 5/50
# 49/49 - 0s - loss: 1.9520 - accuracy: 0.2465 - val_loss: 1.9146 - val_accuracy: 0.2560
# Epoch 6/50
# 49/49 - 0s - loss: 1.8982 - accuracy: 0.2636 - val_loss: 1.8897 - val_accuracy: 0.2666
# Epoch 7/50
# 49/49 - 0s - loss: 1.8652 - accuracy: 0.2793 - val_loss: 1.8462 - val_accuracy: 0.2803
# Epoch 8/50
# 49/49 - 0s - loss: 1.8469 - accuracy: 0.2889 - val_loss: 1.8293 - val_accuracy: 0.2901
# Epoch 9/50
# 49/49 - 0s - loss: 1.8279 - accuracy: 0.2976 - val_loss: 1.8244 - val_accuracy: 0.2928
# Epoch 10/50
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['loss'], label = "train_loss")
plt.plot(history_data.history['val_loss'], label = "val_loss")
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['accuracy'], label = "train_accuracy")
plt.plot(history_data.history['val_accuracy'], label = "val_accuracy")
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# **=> Ở đây có thể quan sát được khi khoảng epoch thứ 12 model đã bị overfiting**

# %% [markdown]
# ### d. 2.MLP-Cifar10-KerasData-ReLU.ipynb

# %%
# relu and adam

import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.cifar10.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images  = test_images / 255.0

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(32,32,3)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_data = model.fit(train_images, train_labels, 
                    validation_data=(test_images, test_labels), 
                    batch_size=1024, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 49/49 - 1s - loss: 2.0372 - accuracy: 0.2500 - val_loss: 1.8700 - val_accuracy: 0.3197
# Epoch 2/50
# 49/49 - 0s - loss: 1.8071 - accuracy: 0.3500 - val_loss: 1.7571 - val_accuracy: 0.3689
# Epoch 3/50
# 49/49 - 0s - loss: 1.7256 - accuracy: 0.3809 - val_loss: 1.6652 - val_accuracy: 0.4024
# Epoch 4/50
# 49/49 - 0s - loss: 1.6452 - accuracy: 0.4110 - val_loss: 1.6198 - val_accuracy: 0.4162
# Epoch 5/50
# 49/49 - 0s - loss: 1.5999 - accuracy: 0.4273 - val_loss: 1.6143 - val_accuracy: 0.4211
# Epoch 6/50
# 49/49 - 0s - loss: 1.5662 - accuracy: 0.4400 - val_loss: 1.5435 - val_accuracy: 0.4499
# Epoch 7/50
# 49/49 - 0s - loss: 1.5300 - accuracy: 0.4521 - val_loss: 1.5420 - val_accuracy: 0.4482
# Epoch 8/50
# 49/49 - 0s - loss: 1.4865 - accuracy: 0.4679 - val_loss: 1.5062 - val_accuracy: 0.4647
# Epoch 9/50
# 49/49 - 0s - loss: 1.4738 - accuracy: 0.4728 - val_loss: 1.4809 - val_accuracy: 0.4702
# Epoch 10/50
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['loss'], label = "train_loss")
plt.plot(history_data.history['val_loss'], label = "val_loss")
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['accuracy'], label = "train_accuracy")
plt.plot(history_data.history['val_accuracy'], label = "val_accuracy")
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# **Nhìn chung khi sử dụng Relu Activation thì model sẽ học nhanh hơn vì có thể tháy được trước epoch thứ 10 model đã overfitting trong khi sigmoid phải khoảng epoch thứ 12. Nhưng kết quả train và valdiation có accuracy không cao nhưng đã bị overfitting**

# %% [markdown]
# ## 2) (Optional) Các bạn thực nghiệm với hàm Tanh, và so sánh với model khi dùng Sigmoid

# %%
import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images = test_images / 255.0

print(train_images.shape)
print(test_images.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %% [markdown]
# Đoạn code này:
# - Khởi tạo weight theo **Normal distribution**
# - Sử dụng **tanh** activation cho hidden layer
# - Optimizer là **sgd**

# %%
# RandomNormal, sigmoid and sgd

import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images  = test_images / 255.0

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='tanh', 
                       kernel_initializer=keras.initializers.RandomNormal(stddev=0.01),
                       bias_initializer=keras.initializers.Zeros()),
    keras.layers.Dense(10, activation='softmax', 
                       kernel_initializer=keras.initializers.RandomNormal(stddev=0.01),
                       bias_initializer=keras.initializers.Zeros())
])

model.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history_data = model.fit(train_images, train_labels,
                         validation_data=(test_images, test_labels), 
                         batch_size=1024, epochs=80, verbose=2)
# Out:
# Epoch 1/80
# 59/59 - 1s - loss: 2.2856 - accuracy: 0.2558 - val_loss: 2.2631 - val_accuracy: 0.3949
# Epoch 2/80
# 59/59 - 0s - loss: 2.2310 - accuracy: 0.4427 - val_loss: 2.1891 - val_accuracy: 0.4814
# Epoch 3/80
# 59/59 - 0s - loss: 2.1276 - accuracy: 0.4975 - val_loss: 2.0524 - val_accuracy: 0.4943
# Epoch 4/80
# 59/59 - 0s - loss: 1.9613 - accuracy: 0.4933 - val_loss: 1.8645 - val_accuracy: 0.4908
# Epoch 5/80
# 59/59 - 0s - loss: 1.7725 - accuracy: 0.5060 - val_loss: 1.6859 - val_accuracy: 0.5106
# Epoch 6/80
# 59/59 - 0s - loss: 1.6108 - accuracy: 0.5277 - val_loss: 1.5438 - val_accuracy: 0.5422
# Epoch 7/80
# 59/59 - 0s - loss: 1.4833 - accuracy: 0.5530 - val_loss: 1.4318 - val_accuracy: 0.5618
# Epoch 8/80
# 59/59 - 0s - loss: 1.3812 - accuracy: 0.5749 - val_loss: 1.3408 - val_accuracy: 0.5766
# Epoch 9/80
# 59/59 - 0s - loss: 1.2969 - accuracy: 0.5894 - val_loss: 1.2648 - val_accuracy: 0.5887
# Epoch 10/80
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['loss'], label = "train_loss")
plt.plot(history_data.history['val_loss'], label = "val_loss")
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['accuracy'], label = "train_accuracy")
plt.plot(history_data.history['val_accuracy'], label = "val_accuracy")
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# Đoạn code này:
# - Khởi tạo weight theo kỹ thuật **Xavier**
# - Sử dụng **tanh** activation cho hidden layer
# - Optimizer là **sgd**

# %%
# Xavier, sigmoid and sgd

import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images  = test_images / 255.0

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='tanh'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history_data = model.fit(train_images, train_labels,
                         validation_data=(test_images, test_labels), 
                         batch_size=1024, epochs=80, verbose=2)
# Out:
# Epoch 1/80
# 59/59 - 1s - loss: 1.7683 - accuracy: 0.4439 - val_loss: 1.3871 - val_accuracy: 0.6135
# Epoch 2/80
# 59/59 - 0s - loss: 1.2231 - accuracy: 0.6551 - val_loss: 1.1110 - val_accuracy: 0.6718
# Epoch 3/80
# 59/59 - 0s - loss: 1.0292 - accuracy: 0.6952 - val_loss: 0.9803 - val_accuracy: 0.6981
# Epoch 4/80
# 59/59 - 0s - loss: 0.9258 - accuracy: 0.7188 - val_loss: 0.9021 - val_accuracy: 0.7154
# Epoch 5/80
# 59/59 - 0s - loss: 0.8596 - accuracy: 0.7353 - val_loss: 0.8487 - val_accuracy: 0.7311
# Epoch 6/80
# 59/59 - 0s - loss: 0.8124 - accuracy: 0.7484 - val_loss: 0.8093 - val_accuracy: 0.7381
# Epoch 7/80
# 59/59 - 0s - loss: 0.7763 - accuracy: 0.7574 - val_loss: 0.7780 - val_accuracy: 0.7466
# Epoch 8/80
# 59/59 - 0s - loss: 0.7474 - accuracy: 0.7654 - val_loss: 0.7529 - val_accuracy: 0.7541
# Epoch 9/80
# 59/59 - 0s - loss: 0.7236 - accuracy: 0.7715 - val_loss: 0.7314 - val_accuracy: 0.7597
# Epoch 10/80
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['loss'], label = "train_loss")
plt.plot(history_data.history['val_loss'], label = "val_loss")
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['accuracy'], label = "train_accuracy")
plt.plot(history_data.history['val_accuracy'], label = "val_accuracy")
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# Đoạn code này:
# - Khởi tạo weight theo kỹ thuật **Xavier**
# - Sử dụng **tanh** activation cho hidden layer
# - Optimizer là **adam**

# %%
# sigmoid and adam

import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images  = test_images / 255.0

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='tanh'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_data = model.fit(train_images, train_labels, 
                    validation_data=(test_images, test_labels), 
                    batch_size=1024, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 59/59 - 1s - loss: 0.8001 - accuracy: 0.7286 - val_loss: 0.5651 - val_accuracy: 0.8039
# Epoch 2/50
# 59/59 - 0s - loss: 0.4998 - accuracy: 0.8264 - val_loss: 0.4985 - val_accuracy: 0.8223
# Epoch 3/50
# 59/59 - 0s - loss: 0.4482 - accuracy: 0.8425 - val_loss: 0.4606 - val_accuracy: 0.8357
# Epoch 4/50
# 59/59 - 0s - loss: 0.4188 - accuracy: 0.8523 - val_loss: 0.4492 - val_accuracy: 0.8374
# Epoch 5/50
# 59/59 - 0s - loss: 0.3993 - accuracy: 0.8593 - val_loss: 0.4263 - val_accuracy: 0.8475
# Epoch 6/50
# 59/59 - 0s - loss: 0.3823 - accuracy: 0.8643 - val_loss: 0.4125 - val_accuracy: 0.8522
# Epoch 7/50
# 59/59 - 0s - loss: 0.3685 - accuracy: 0.8699 - val_loss: 0.4071 - val_accuracy: 0.8518
# Epoch 8/50
# 59/59 - 0s - loss: 0.3579 - accuracy: 0.8728 - val_loss: 0.3976 - val_accuracy: 0.8575
# Epoch 9/50
# 59/59 - 0s - loss: 0.3487 - accuracy: 0.8756 - val_loss: 0.3876 - val_accuracy: 0.8617
# Epoch 10/50
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['loss'], label = "train_loss")
plt.plot(history_data.history['val_loss'], label = "val_loss")
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['accuracy'], label = "train_accuracy")
plt.plot(history_data.history['val_accuracy'], label = "val_accuracy")
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %%
# sigmoid and adam

import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images  = test_images / 255.0

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='tanh'),
    keras.layers.Dense(128, activation='tanh'),
    keras.layers.Dense(128, activation='tanh'),
    keras.layers.Dense(128, activation='tanh'),
    keras.layers.Dense(128, activation='tanh'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_data = model.fit(train_images, train_labels, 
                    validation_data=(test_images, test_labels), 
                    batch_size=1024, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 59/59 - 1s - loss: 0.7186 - accuracy: 0.7482 - val_loss: 0.4880 - val_accuracy: 0.8215
# Epoch 2/50
# 59/59 - 0s - loss: 0.4195 - accuracy: 0.8490 - val_loss: 0.4234 - val_accuracy: 0.8466
# Epoch 3/50
# 59/59 - 0s - loss: 0.3774 - accuracy: 0.8633 - val_loss: 0.4075 - val_accuracy: 0.8519
# Epoch 4/50
# 59/59 - 0s - loss: 0.3565 - accuracy: 0.8713 - val_loss: 0.3886 - val_accuracy: 0.8609
# Epoch 5/50
# 59/59 - 0s - loss: 0.3370 - accuracy: 0.8767 - val_loss: 0.3974 - val_accuracy: 0.8553
# Epoch 6/50
# 59/59 - 0s - loss: 0.3323 - accuracy: 0.8776 - val_loss: 0.3657 - val_accuracy: 0.8688
# Epoch 7/50
# 59/59 - 0s - loss: 0.3113 - accuracy: 0.8855 - val_loss: 0.3528 - val_accuracy: 0.8734
# Epoch 8/50
# 59/59 - 0s - loss: 0.2983 - accuracy: 0.8899 - val_loss: 0.3613 - val_accuracy: 0.8691
# Epoch 9/50
# 59/59 - 0s - loss: 0.2959 - accuracy: 0.8913 - val_loss: 0.3534 - val_accuracy: 0.8714
# Epoch 10/50
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['loss'], label = "train_loss")
plt.plot(history_data.history['val_loss'], label = "val_loss")
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['accuracy'], label = "train_accuracy")
plt.plot(history_data.history['val_accuracy'], label = "val_accuracy")
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
#  1/
#
# **Normal distribution**, **sigmoid**, **sgd**  -> train:70%, val:70%
#
# **Normal distribution**, **tanh**, **sgd**  -> train:82%, val:80%
#
#  2/
#
#  **Xavier**, **sigmoid**, **sgd**  -> train:77% val:76%
#
#  **Xavier**, **tanh**, **sgd**  -> train:84% val:83%
#
#  3/
#
# **Xavier**, **sigmoid**, **adam**  -> train:90% val:88%
#
# **Xavier**, **tanh**, **adam**  -> train:93% val:88%
#
#  4/
#
#  **Xavier**, **sigmoid**, **adam**  -> train:92% val:87%
#
#  **Xavier**, **tanh**, **adam**  -> train:96% val:88%
#
#  **=> Từ đây ta có thể thấy được:**
#
# **- Nhìn chung khi sử dụng hàm tanh thì tất cả các bước thử khởi tạo đều có accuracy cao hơn so với khi sử dụng sigmoid đối với tập data này (Fashion mnist).**
#
# **- Khi sử dụng optimizer là sgd thì tanh đều trội hơn rất nhiều so với sigmoid lớn hơn từ 7-12%.**
#
# **Tuy nhiên, khi sủ dụng optimizer admam thì sự khác biệt được rút ngắn lại, và dường như không có thay đổi ở tập validation. Mặc dù tố độ hội tụ và overfitting của tanh nhanh hơn sigmoid.**

# %% [markdown]
# ## 3) (Optional) Các bạn chọn 1 một model cố định, sau đó chạy thực nghiệm với các loại data normalization khác nhau. Sau đó các bạn so sánh kết quả và đưa ra các kết luận các bạn rút ra được.

# %% [markdown]
# Model test được sử dụng là 1 input, 1 hidden (128 units), 1 output layer, dùng kỹ thuật Xavier, activation là relu và optimizer là adam.
#
# 3 kỹ thuật normalization được thực hiện: normalization range [0, 1], normalization range [-1, 1], z-score normalization

# %% [markdown]
# ### Normalization range [0, 1]

# %%
# Xavier, sigmoid and sgd

import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images  = test_images / 255.0

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history_data = model.fit(train_images, train_labels,
                         validation_data=(test_images, test_labels), 
                         batch_size=1024, epochs=80, verbose=2)
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step
# Epoch 1/80
# 59/59 - 2s - loss: 0.8488 - accuracy: 0.7149 - val_loss: 0.5806 - val_accuracy: 0.7983
# Epoch 2/80
# 59/59 - 0s - loss: 0.5121 - accuracy: 0.8267 - val_loss: 0.5082 - val_accuracy: 0.8228
# Epoch 3/80
# 59/59 - 0s - loss: 0.4608 - accuracy: 0.8428 - val_loss: 0.4787 - val_accuracy: 0.8323
# Epoch 4/80
# 59/59 - 0s - loss: 0.4296 - accuracy: 0.8526 - val_loss: 0.4534 - val_accuracy: 0.8410
# Epoch 5/80
# 59/59 - 0s - loss: 0.4073 - accuracy: 0.8593 - val_loss: 0.4351 - val_accuracy: 0.8476
# Epoch 6/80
# 59/59 - 0s - loss: 0.3898 - accuracy: 0.8650 - val_loss: 0.4497 - val_accuracy: 0.8368
# Epoch 7/80
# 59/59 - 0s - loss: 0.3829 - accuracy: 0.8663 - val_loss: 0.4153 - val_accuracy: 0.8528
# Epoch 8/80
# 59/59 - 0s - loss: 0.3664 - accuracy: 0.8719 - val_loss: 0.4084 - val_accuracy: 0.8574
# Epoch 9/80
# 59/59 - 0s - loss: 0.3575 - accuracy: 0.8750 - val_loss: 0.3935 - val_accuracy: 0.8635
# Epoch 10/80
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['loss'], label = "train_loss")
plt.plot(history_data.history['val_loss'], label = "val_loss")
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['accuracy'], label = "train_accuracy")
plt.plot(history_data.history['val_accuracy'], label = "val_accuracy")
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# ### Normalization range [-1, 1]

# %%
# Xavier, sigmoid and sgd

import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

train_images = (train_images / 127.5) - 1.0
test_images  = (test_images / 127.5) - 1.0 

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history_data = model.fit(train_images, train_labels,
                         validation_data=(test_images, test_labels), 
                         batch_size=1024, epochs=80, verbose=2)
# Out:
# Epoch 1/80
# 59/59 - 1s - loss: 0.8078 - accuracy: 0.7188 - val_loss: 0.5320 - val_accuracy: 0.8087
# Epoch 2/80
# 59/59 - 0s - loss: 0.4655 - accuracy: 0.8356 - val_loss: 0.4745 - val_accuracy: 0.8291
# Epoch 3/80
# 59/59 - 0s - loss: 0.4215 - accuracy: 0.8511 - val_loss: 0.4447 - val_accuracy: 0.8385
# Epoch 4/80
# 59/59 - 0s - loss: 0.3931 - accuracy: 0.8622 - val_loss: 0.4210 - val_accuracy: 0.8512
# Epoch 5/80
# 59/59 - 0s - loss: 0.3740 - accuracy: 0.8679 - val_loss: 0.4140 - val_accuracy: 0.8505
# Epoch 6/80
# 59/59 - 0s - loss: 0.3560 - accuracy: 0.8745 - val_loss: 0.4054 - val_accuracy: 0.8545
# Epoch 7/80
# 59/59 - 0s - loss: 0.3427 - accuracy: 0.8782 - val_loss: 0.3860 - val_accuracy: 0.8631
# Epoch 8/80
# 59/59 - 0s - loss: 0.3342 - accuracy: 0.8812 - val_loss: 0.3820 - val_accuracy: 0.8628
# Epoch 9/80
# 59/59 - 0s - loss: 0.3235 - accuracy: 0.8843 - val_loss: 0.3765 - val_accuracy: 0.8665
# Epoch 10/80
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['loss'], label = "train_loss")
plt.plot(history_data.history['val_loss'], label = "val_loss")
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['accuracy'], label = "train_accuracy")
plt.plot(history_data.history['val_accuracy'], label = "val_accuracy")
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# ### Z-score Normalization

# %%
# Xavier, sigmoid and sgd

import tensorflow as tf
from tensorflow import keras
import numpy as np
# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

train_images = (train_images-np.mean(train_images))/np.std(train_images)
test_images  = (test_images-np.mean(test_images))/np.std(test_images) 

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history_data = model.fit(train_images, train_labels,
                         validation_data=(test_images, test_labels), 
                         batch_size=1024, epochs=80, verbose=2)
# Out:
# Epoch 1/80
# 59/59 - 1s - loss: 0.6946 - accuracy: 0.7541 - val_loss: 0.4890 - val_accuracy: 0.8232
# Epoch 2/80
# 59/59 - 0s - loss: 0.4261 - accuracy: 0.8482 - val_loss: 0.4382 - val_accuracy: 0.8393
# Epoch 3/80
# 59/59 - 0s - loss: 0.3824 - accuracy: 0.8643 - val_loss: 0.4154 - val_accuracy: 0.8499
# Epoch 4/80
# 59/59 - 0s - loss: 0.3554 - accuracy: 0.8726 - val_loss: 0.3950 - val_accuracy: 0.8578
# Epoch 5/80
# 59/59 - 0s - loss: 0.3353 - accuracy: 0.8804 - val_loss: 0.3898 - val_accuracy: 0.8586
# Epoch 6/80
# 59/59 - 0s - loss: 0.3211 - accuracy: 0.8838 - val_loss: 0.3761 - val_accuracy: 0.8647
# Epoch 7/80
# 59/59 - 0s - loss: 0.3053 - accuracy: 0.8904 - val_loss: 0.3558 - val_accuracy: 0.8729
# Epoch 8/80
# 59/59 - 0s - loss: 0.2925 - accuracy: 0.8945 - val_loss: 0.3574 - val_accuracy: 0.8709
# Epoch 9/80
# 59/59 - 0s - loss: 0.2842 - accuracy: 0.8974 - val_loss: 0.3594 - val_accuracy: 0.8695
# Epoch 10/80
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['loss'], label = "train_loss")
plt.plot(history_data.history['val_loss'], label = "val_loss")
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['accuracy'], label = "train_accuracy")
plt.plot(history_data.history['val_accuracy'], label = "val_accuracy")
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# **=> Kết quả thực nghiệm:**
# **- Normalize range [0, 1]: train:94% val:88% **
# **- Normalize range [-1, 1]: train:96% val:88% **
# **- Z-score Normalize: train:98% val:88% **
# **=> Từ kết quả thực nghiệm: có thể nhận thấy rằng khi normalize data kết quả học được cải thiện đáng kể so với khi không normalize data (cải thiện gần 10%). Bên cạnh đó kết quả tuy bị overfitting train tăng val dường như đứng yên nhưng cũng thể hiện được Z-score Normalize có khả năng giúp cho model học nhanh nhất  với train lên đến 98%, tiếp đền là Normalize range [-1, 1] 96%, và còn lại là Normalize range [0, 1]**

# %% [markdown]
# ## 4) (Optional) Các bạn làm tương tự câu (4) cho 3 loại Weight Initialization đã học (Gaussian với mean=0, sdv=0.01; Glorot và He). So sánh kết qua khi thực nghiệm với cùng điều kiện.

# %% [markdown]
# ### Gaussian với mean=0, sdv=0.01

# %%
# Xavier, sigmoid and sgd

import tensorflow as tf
from tensorflow import keras
import numpy as np
# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

train_images = (train_images-np.mean(train_images))/np.std(train_images)
test_images  = (test_images-np.mean(test_images))/np.std(test_images) 

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu', kernel_initializer=keras.initializers.RandomNormal(stddev=0.01),
                       bias_initializer=keras.initializers.Zeros()),
    keras.layers.Dense(10, activation='softmax', kernel_initializer=keras.initializers.RandomNormal(stddev=0.01),
                       bias_initializer=keras.initializers.Zeros())
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history_data = model.fit(train_images, train_labels,
                         validation_data=(test_images, test_labels), 
                         batch_size=1024, epochs=80, verbose=2)
# Out:
# Epoch 1/80
# 59/59 - 1s - loss: 0.9209 - accuracy: 0.7066 - val_loss: 0.5720 - val_accuracy: 0.7930
# Epoch 2/80
# 59/59 - 0s - loss: 0.4914 - accuracy: 0.8254 - val_loss: 0.4811 - val_accuracy: 0.8251
# Epoch 3/80
# 59/59 - 0s - loss: 0.4325 - accuracy: 0.8464 - val_loss: 0.4443 - val_accuracy: 0.8417
# Epoch 4/80
# 59/59 - 0s - loss: 0.4007 - accuracy: 0.8581 - val_loss: 0.4265 - val_accuracy: 0.8484
# Epoch 5/80
# 59/59 - 0s - loss: 0.3794 - accuracy: 0.8650 - val_loss: 0.4174 - val_accuracy: 0.8471
# Epoch 6/80
# 59/59 - 0s - loss: 0.3590 - accuracy: 0.8710 - val_loss: 0.3963 - val_accuracy: 0.8597
# Epoch 7/80
# 59/59 - 0s - loss: 0.3440 - accuracy: 0.8770 - val_loss: 0.3906 - val_accuracy: 0.8606
# Epoch 8/80
# 59/59 - 0s - loss: 0.3328 - accuracy: 0.8803 - val_loss: 0.3773 - val_accuracy: 0.8674
# Epoch 9/80
# 59/59 - 0s - loss: 0.3219 - accuracy: 0.8839 - val_loss: 0.3703 - val_accuracy: 0.8676
# Epoch 10/80
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['loss'], label = "train_loss")
plt.plot(history_data.history['val_loss'], label = "val_loss")
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['accuracy'], label = "train_accuracy")
plt.plot(history_data.history['val_accuracy'], label = "val_accuracy")
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %%
# Xavier, sigmoid and sgd

import tensorflow as tf
from tensorflow import keras
import numpy as np
# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images  = test_images / 255.0

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu', kernel_initializer=keras.initializers.RandomNormal(stddev=0.01),
                       bias_initializer=keras.initializers.Zeros()),
    keras.layers.Dense(10, activation='softmax', kernel_initializer=keras.initializers.RandomNormal(stddev=0.01),
                       bias_initializer=keras.initializers.Zeros())
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history_data = model.fit(train_images, train_labels,
                         validation_data=(test_images, test_labels), 
                         batch_size=1024, epochs=80, verbose=2)
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step
# Epoch 1/80
# 59/59 - 2s - loss: 1.2589 - accuracy: 0.5978 - val_loss: 0.7520 - val_accuracy: 0.7105
# Epoch 2/80
# 59/59 - 0s - loss: 0.6310 - accuracy: 0.7759 - val_loss: 0.5818 - val_accuracy: 0.7922
# Epoch 3/80
# 59/59 - 0s - loss: 0.5210 - accuracy: 0.8206 - val_loss: 0.5147 - val_accuracy: 0.8218
# Epoch 4/80
# 59/59 - 0s - loss: 0.4719 - accuracy: 0.8376 - val_loss: 0.4933 - val_accuracy: 0.8260
# Epoch 5/80
# 59/59 - 0s - loss: 0.4443 - accuracy: 0.8459 - val_loss: 0.4670 - val_accuracy: 0.8343
# Epoch 6/80
# 59/59 - 0s - loss: 0.4256 - accuracy: 0.8533 - val_loss: 0.4481 - val_accuracy: 0.8427
# Epoch 7/80
# 59/59 - 0s - loss: 0.4096 - accuracy: 0.8578 - val_loss: 0.4341 - val_accuracy: 0.8482
# Epoch 8/80
# 59/59 - 0s - loss: 0.3942 - accuracy: 0.8636 - val_loss: 0.4231 - val_accuracy: 0.8526
# Epoch 9/80
# 59/59 - 0s - loss: 0.3833 - accuracy: 0.8677 - val_loss: 0.4150 - val_accuracy: 0.8545
# Epoch 10/80
# ...

# %% [markdown]
# ### Glorot

# %%
# Xavier, sigmoid and sgd

import tensorflow as tf
from tensorflow import keras
import numpy as np
# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

train_images = (train_images-np.mean(train_images))/np.std(train_images)
test_images  = (test_images-np.mean(test_images))/np.std(test_images) 

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history_data = model.fit(train_images, train_labels,
                         validation_data=(test_images, test_labels), 
                         batch_size=1024, epochs=80, verbose=2)
# Out:
# Epoch 1/80
# 59/59 - 1s - loss: 0.7243 - accuracy: 0.7494 - val_loss: 0.4977 - val_accuracy: 0.8221
# Epoch 2/80
# 59/59 - 0s - loss: 0.4359 - accuracy: 0.8453 - val_loss: 0.4507 - val_accuracy: 0.8361
# Epoch 3/80
# 59/59 - 0s - loss: 0.3927 - accuracy: 0.8601 - val_loss: 0.4200 - val_accuracy: 0.8503
# Epoch 4/80
# 59/59 - 0s - loss: 0.3633 - accuracy: 0.8702 - val_loss: 0.3947 - val_accuracy: 0.8584
# Epoch 5/80
# 59/59 - 0s - loss: 0.3428 - accuracy: 0.8773 - val_loss: 0.3798 - val_accuracy: 0.8637
# Epoch 6/80
# 59/59 - 0s - loss: 0.3254 - accuracy: 0.8839 - val_loss: 0.3659 - val_accuracy: 0.8671
# Epoch 7/80
# 59/59 - 0s - loss: 0.3106 - accuracy: 0.8890 - val_loss: 0.3614 - val_accuracy: 0.8733
# Epoch 8/80
# 59/59 - 0s - loss: 0.3003 - accuracy: 0.8921 - val_loss: 0.3560 - val_accuracy: 0.8717
# Epoch 9/80
# 59/59 - 0s - loss: 0.2905 - accuracy: 0.8954 - val_loss: 0.3595 - val_accuracy: 0.8716
# Epoch 10/80
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['loss'], label = "train_loss")
plt.plot(history_data.history['val_loss'], label = "val_loss")
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['accuracy'], label = "train_accuracy")
plt.plot(history_data.history['val_accuracy'], label = "val_accuracy")
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %%
# Xavier, sigmoid and sgd

import tensorflow as tf
from tensorflow import keras
import numpy as np
# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images  = test_images / 255.0

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history_data = model.fit(train_images, train_labels,
                         validation_data=(test_images, test_labels), 
                         batch_size=1024, epochs=80, verbose=2)
# Out:
# Epoch 1/80
# 59/59 - 1s - loss: 0.8543 - accuracy: 0.7222 - val_loss: 0.5832 - val_accuracy: 0.8034
# Epoch 2/80
# 59/59 - 0s - loss: 0.5187 - accuracy: 0.8249 - val_loss: 0.5050 - val_accuracy: 0.8291
# Epoch 3/80
# 59/59 - 0s - loss: 0.4629 - accuracy: 0.8440 - val_loss: 0.4775 - val_accuracy: 0.8355
# Epoch 4/80
# 59/59 - 0s - loss: 0.4317 - accuracy: 0.8518 - val_loss: 0.4657 - val_accuracy: 0.8384
# Epoch 5/80
# 59/59 - 0s - loss: 0.4110 - accuracy: 0.8577 - val_loss: 0.4441 - val_accuracy: 0.8450
# Epoch 6/80
# 59/59 - 0s - loss: 0.3935 - accuracy: 0.8631 - val_loss: 0.4287 - val_accuracy: 0.8518
# Epoch 7/80
# 59/59 - 0s - loss: 0.3796 - accuracy: 0.8689 - val_loss: 0.4156 - val_accuracy: 0.8536
# Epoch 8/80
# 59/59 - 0s - loss: 0.3646 - accuracy: 0.8731 - val_loss: 0.4055 - val_accuracy: 0.8568
# Epoch 9/80
# 59/59 - 0s - loss: 0.3542 - accuracy: 0.8774 - val_loss: 0.4006 - val_accuracy: 0.8557
# Epoch 10/80
# ...

# %% [markdown]
# ### He

# %%
# Xavier, sigmoid and sgd

import tensorflow as tf
from tensorflow import keras
import numpy as np
# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

train_images = (train_images-np.mean(train_images))/np.std(train_images)
test_images  = (test_images-np.mean(test_images))/np.std(test_images) 

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu', kernel_initializer=tf.keras.initializers.HeUniform()),
    keras.layers.Dense(10, activation='softmax', kernel_initializer=tf.keras.initializers.HeUniform())
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history_data = model.fit(train_images, train_labels,
                         validation_data=(test_images, test_labels), 
                         batch_size=1024, epochs=80, verbose=2)
# Out:
# Epoch 1/80
# 59/59 - 1s - loss: 0.7326 - accuracy: 0.7440 - val_loss: 0.5066 - val_accuracy: 0.8161
# Epoch 2/80
# 59/59 - 0s - loss: 0.4401 - accuracy: 0.8434 - val_loss: 0.4428 - val_accuracy: 0.8437
# Epoch 3/80
# 59/59 - 0s - loss: 0.3922 - accuracy: 0.8608 - val_loss: 0.4223 - val_accuracy: 0.8480
# Epoch 4/80
# 59/59 - 0s - loss: 0.3663 - accuracy: 0.8697 - val_loss: 0.4052 - val_accuracy: 0.8562
# Epoch 5/80
# 59/59 - 0s - loss: 0.3453 - accuracy: 0.8773 - val_loss: 0.3917 - val_accuracy: 0.8572
# Epoch 6/80
# 59/59 - 0s - loss: 0.3297 - accuracy: 0.8823 - val_loss: 0.3816 - val_accuracy: 0.8641
# Epoch 7/80
# 59/59 - 0s - loss: 0.3170 - accuracy: 0.8860 - val_loss: 0.3707 - val_accuracy: 0.8690
# Epoch 8/80
# 59/59 - 0s - loss: 0.3056 - accuracy: 0.8903 - val_loss: 0.3644 - val_accuracy: 0.8702
# Epoch 9/80
# 59/59 - 0s - loss: 0.2948 - accuracy: 0.8940 - val_loss: 0.3584 - val_accuracy: 0.8694
# Epoch 10/80
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['loss'], label = "train_loss")
plt.plot(history_data.history['val_loss'], label = "val_loss")
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(history_data.history['accuracy'], label = "train_accuracy")
plt.plot(history_data.history['val_accuracy'], label = "val_accuracy")
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()

# %%
# Xavier, sigmoid and sgd

import tensorflow as tf
from tensorflow import keras
import numpy as np
# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images  = test_images / 255.0

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu', kernel_initializer=tf.keras.initializers.HeUniform()),
    keras.layers.Dense(10, activation='softmax', kernel_initializer=tf.keras.initializers.HeUniform())
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history_data = model.fit(train_images, train_labels,
                         validation_data=(test_images, test_labels), 
                         batch_size=1024, epochs=80, verbose=2)
# Out:
# Epoch 1/80
# 59/59 - 1s - loss: 0.8632 - accuracy: 0.7131 - val_loss: 0.5853 - val_accuracy: 0.8014
# Epoch 2/80
# 59/59 - 0s - loss: 0.5129 - accuracy: 0.8265 - val_loss: 0.5053 - val_accuracy: 0.8241
# Epoch 3/80
# 59/59 - 0s - loss: 0.4574 - accuracy: 0.8438 - val_loss: 0.4661 - val_accuracy: 0.8386
# Epoch 4/80
# 59/59 - 0s - loss: 0.4236 - accuracy: 0.8544 - val_loss: 0.4515 - val_accuracy: 0.8407
# Epoch 5/80
# 59/59 - 0s - loss: 0.4042 - accuracy: 0.8602 - val_loss: 0.4369 - val_accuracy: 0.8448
# Epoch 6/80
# 59/59 - 0s - loss: 0.3858 - accuracy: 0.8665 - val_loss: 0.4214 - val_accuracy: 0.8526
# Epoch 7/80
# 59/59 - 0s - loss: 0.3729 - accuracy: 0.8702 - val_loss: 0.4029 - val_accuracy: 0.8580
# Epoch 8/80
# 59/59 - 0s - loss: 0.3598 - accuracy: 0.8747 - val_loss: 0.4135 - val_accuracy: 0.8544
# Epoch 9/80
# 59/59 - 0s - loss: 0.3515 - accuracy: 0.8762 - val_loss: 0.3881 - val_accuracy: 0.8645
# Epoch 10/80
# ...

# %% [markdown]
# **=> Kết quả thực nghiệm:**
# **- Gaussian mean 0, stdv 0.01: train:97% val:89% **
# **- Xavier : train:98% val:88% **
# **- HE: train:98% val:89% **
# **=> Từ kết quả thực nghiệm: có thể nhận thấy rằng sau khi normalize data (Z-score) kết hợp  các kỹ thuật khởi tạo weight kết quả hầu như không cải thiện có thể do model đã học gần như rất tốt 98% . Do đó sẽ thử nghiệm các kỹ thuật này với normalization range [0,1]**

# %% [markdown]
# **=> Kết quả thực nghiệm:**
# **- Gaussian mean 0, stdv 0.01: train:92% val:88% **
# **- Xavier : train:94% val:88% **
# **- HE: train:94% val:88% **
# **=> Từ kết quả thực nghiệm: có thể nhận thấy rằng sau khi normalize data (normalization range [0,1]), He và Xavier cho kết quả giống nhau và tốt hơn Gaussian mean 0 và stdv 0.01**

# %% [markdown]
# ## References
